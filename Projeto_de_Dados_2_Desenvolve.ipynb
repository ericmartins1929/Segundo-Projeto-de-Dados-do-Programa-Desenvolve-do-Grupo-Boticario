# %% [markdown]
# <a href="https://colab.research.google.com/github/ericmartins1929/Segundo-Projeto-de-Dados-do-Programa-Desenvolve-do-Grupo-Boticario/blob/main/Projeto_de_Dados_2_Desenvolve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importando o dataset

# %%
dados = pd.read_csv("/content/base-alugueis-sp.csv")
dados
# Out:
#                                address                 district  area  \
# 0                           Rua Herval               Belenzinho    21
# 1                   Avenida São Miguel             Vila Marieta    15
# 2                     Rua Oscar Freire                Pinheiros    18
# 3                     Rua Júlio Sayago                  Vila Ré    56
# 4                   Rua Barata Ribeiro               Bela Vista    19
# ...                                ...                      ...   ...
# 11652          Avenida Adolfo Pinheiro              Santo Amaro    94
# 11653  Rua Professor Alexandre Correia     Jardim Vitória Régia   350
# 11654                 Rua Abílio Borin         Jardim Caravelas    84
# 11655                Rua Forte William  Jardim Fonte do Morumbi    76
# 11656              Rua Alexandre Dumas              Santo Amaro   110
#
#        bedrooms  garage                type   rent  total
# 0             1       0     Studio e kitnet   2400   2939
# ...

# %%
dados.describe()
# Out:
#                area      bedrooms        garage          rent         total
# count  11657.000000  11657.000000  11657.000000  11657.000000  11657.000000
# mean      84.655658      1.966286      1.060393   3250.814789   4080.030625
# std       74.020536      0.931313      1.132349   2650.711557   3352.480274
# min        0.000000      0.000000      0.000000    500.000000    509.000000
# 25%       40.000000      1.000000      0.000000   1590.000000   1996.000000
# 50%       60.000000      2.000000      1.000000   2415.000000   3057.000000
# 75%       96.000000      3.000000      2.000000   3800.000000   4774.000000
# max      580.000000      6.000000      6.000000  25000.000000  28700.000000

# %% [markdown]
# ### Tratando o dataset

# %%
dados_sp =dados.rename(columns= {'address':'endereço','district':'distrito','area':'área','bedrooms':'quartos',
                                 'garage':'garagem','type':'tipo','rent':'aluguel','total':'valor_total'})
dados_sp

### Renomeando as colunas , tirando nomes em inglês e colocando nomes em portguês
# Out:
#                               endereço                 distrito  área  \
# 0                           Rua Herval               Belenzinho    21
# 1                   Avenida São Miguel             Vila Marieta    15
# 2                     Rua Oscar Freire                Pinheiros    18
# 3                     Rua Júlio Sayago                  Vila Ré    56
# 4                   Rua Barata Ribeiro               Bela Vista    19
# ...                                ...                      ...   ...
# 11652          Avenida Adolfo Pinheiro              Santo Amaro    94
# 11653  Rua Professor Alexandre Correia     Jardim Vitória Régia   350
# 11654                 Rua Abílio Borin         Jardim Caravelas    84
# 11655                Rua Forte William  Jardim Fonte do Morumbi    76
# 11656              Rua Alexandre Dumas              Santo Amaro   110
#
#        quartos  garagem                tipo  aluguel  valor_total
# ...

# %%
dados_sp['valor_por_m2'] = dados_sp['aluguel']/dados_sp['área']
dados_sp

## Descobrindo o valor por m²
# Out:
#                               endereço                 distrito  área  \
# 0                           Rua Herval               Belenzinho    21
# 1                   Avenida São Miguel             Vila Marieta    15
# 2                     Rua Oscar Freire                Pinheiros    18
# 3                     Rua Júlio Sayago                  Vila Ré    56
# 4                   Rua Barata Ribeiro               Bela Vista    19
# ...                                ...                      ...   ...
# 11652          Avenida Adolfo Pinheiro              Santo Amaro    94
# 11653  Rua Professor Alexandre Correia     Jardim Vitória Régia   350
# 11654                 Rua Abílio Borin         Jardim Caravelas    84
# 11655                Rua Forte William  Jardim Fonte do Morumbi    76
# 11656              Rua Alexandre Dumas              Santo Amaro   110
#
#        quartos  garagem                tipo  aluguel  valor_total  \
# ...

# %%
dados_sp['custo'] = dados_sp['valor_total']- dados_sp['aluguel']
dados_sp

### Descobrindo o custo
# Out:
#                               endereço                 distrito  área  \
# 0                           Rua Herval               Belenzinho    21
# 1                   Avenida São Miguel             Vila Marieta    15
# 2                     Rua Oscar Freire                Pinheiros    18
# 3                     Rua Júlio Sayago                  Vila Ré    56
# 4                   Rua Barata Ribeiro               Bela Vista    19
# ...                                ...                      ...   ...
# 11652          Avenida Adolfo Pinheiro              Santo Amaro    94
# 11653  Rua Professor Alexandre Correia     Jardim Vitória Régia   350
# 11654                 Rua Abílio Borin         Jardim Caravelas    84
# 11655                Rua Forte William  Jardim Fonte do Morumbi    76
# 11656              Rua Alexandre Dumas              Santo Amaro   110
#
#        quartos  garagem                tipo  aluguel  valor_total  \
# ...

# %%
dados_sp.shape
# Out:
# (11657, 10)

# %%
dados_sp.isnull()

## Verificando se tem dadas em brancos da amostra
# Out:
#        endereço  distrito   área  quartos  garagem   tipo  aluguel  \
# 0         False     False  False    False    False  False    False
# 1         False     False  False    False    False  False    False
# 2         False     False  False    False    False  False    False
# 3         False     False  False    False    False  False    False
# 4         False     False  False    False    False  False    False
# ...         ...       ...    ...      ...      ...    ...      ...
# 11652     False     False  False    False    False  False    False
# 11653     False     False  False    False    False  False    False
# 11654     False     False  False    False    False  False    False
# 11655     False     False  False    False    False  False    False
# 11656     False     False  False    False    False  False    False
#
#        valor_total  valor_por_m2  custo
# 0            False         False  False
# 1            False         False  False
# ...

# %%
dados_sp.isnull().sum()
# Out:
# endereço        0
# distrito        0
# área            0
# quartos         0
# garagem         0
# tipo            0
# aluguel         0
# valor_total     0
# valor_por_m2    0
# custo           0
# dtype: int64

# %%
dados_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11657 entries, 0 to 11656
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   endereço      11657 non-null  object
#  1   distrito      11657 non-null  object
#  2   área          11657 non-null  int64
#  3   quartos       11657 non-null  int64
#  4   garagem       11657 non-null  int64
#  5   tipo          11657 non-null  object
#  6   aluguel       11657 non-null  int64
#  7   valor_total   11657 non-null  int64
#  8   valor_por_m2  11657 non-null  float64
#  9   custo         11657 non-null  int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 910.8+ KB

# %%
dados_sp.query("quartos == 0 |área == 0")
# Out:
#                                 endereço                       distrito  área  \
# 71               Rua Natividade Saldanha                      São Lucas    22
# 98               Rua Natividade Saldanha                      São Lucas    19
# 163                Rua João José Pacheco            Jardim Vila Mariana    22
# 259                  Rua Riskallah Jorge  Centro Histórico de São Paulo    28
# 476    Rua Doutor Miguel Vieira Ferreira                        Tatuapé    30
# 493              Rua Natividade Saldanha                      São Lucas    32
# 569           Rua Albino Boldasso Gabril                  Vila Cruzeiro    44
# 604              Rua Natividade Saldanha                      São Lucas    29
# 631                     Avenida São João                  Santa Cecilia    35
# 708          Rua Doutor Albuquerque Lins                  Santa Cecília    63
# 1002             Rua Natividade Saldanha                      São Lucas    28
# ...

# %%
dados_sp.query("área == 0")

### Verificando na amostra quais são as áreas igual a zero . O meu objetivo é remover isso da análise
# Out:
# Empty DataFrame
# Columns: [endereço, distrito, área, quartos, garagem, tipo, aluguel, valor_total, valor_por_m2, custo]
# Index: []

# %%
dados_sp.query("área == 0").index
# Out:
# Index([], dtype='int64')

# %%
registros_remover = dados_sp.query("área == 0").index

# %%
dados_sp.drop(registros_remover,axis=0 , inplace = True )

# %%
dados_sp.query("área == 0")
# Out:
# Empty DataFrame
# Columns: [endereço, distrito, área, quartos, garagem, tipo, aluguel, valor_total, valor_por_m2, custo]
# Index: []

# %%
dados_sp.query("quartos == 0")
# Out:
#                                 endereço                       distrito  área  \
# 71               Rua Natividade Saldanha                      São Lucas    22
# 98               Rua Natividade Saldanha                      São Lucas    19
# 163                Rua João José Pacheco            Jardim Vila Mariana    22
# 259                  Rua Riskallah Jorge  Centro Histórico de São Paulo    28
# 476    Rua Doutor Miguel Vieira Ferreira                        Tatuapé    30
# 493              Rua Natividade Saldanha                      São Lucas    32
# 569           Rua Albino Boldasso Gabril                  Vila Cruzeiro    44
# 604              Rua Natividade Saldanha                      São Lucas    29
# 631                     Avenida São João                  Santa Cecilia    35
# 708          Rua Doutor Albuquerque Lins                  Santa Cecília    63
# 1002             Rua Natividade Saldanha                      São Lucas    28
# ...

# %%
condicao = (dados_sp['tipo'] == 'Apartamento') & (dados_sp['quartos'] == 0)
dados_sp= dados_sp.loc[~condicao]
dados_sp

### Verificando na amostra quais são dos dados que tem tipo como apartamento e aonde os quartos são 0  . O meu objetivo é remover isso da análise de dados
# Out:
#                               endereço                 distrito  área  \
# 0                           Rua Herval               Belenzinho    21
# 1                   Avenida São Miguel             Vila Marieta    15
# 2                     Rua Oscar Freire                Pinheiros    18
# 3                     Rua Júlio Sayago                  Vila Ré    56
# 4                   Rua Barata Ribeiro               Bela Vista    19
# ...                                ...                      ...   ...
# 11652          Avenida Adolfo Pinheiro              Santo Amaro    94
# 11653  Rua Professor Alexandre Correia     Jardim Vitória Régia   350
# 11654                 Rua Abílio Borin         Jardim Caravelas    84
# 11655                Rua Forte William  Jardim Fonte do Morumbi    76
# 11656              Rua Alexandre Dumas              Santo Amaro   110
#
#        quartos  garagem                tipo  aluguel  valor_total  \
# ...

# %%
condicao1 = (dados_sp['tipo'] == 'Studio e kitnet') & (dados_sp['quartos'] == 6)
dados_sp= dados_sp.loc[~condicao1]
dados_sp

### Remover na amostra o  dados que tem tipo como Studio e Kitnet e aonde os quartos são 6 . O meu objetivo é remover o outlier na análise de dados
# Out:
#                               endereço                 distrito  área  \
# 0                           Rua Herval               Belenzinho    21
# 1                   Avenida São Miguel             Vila Marieta    15
# 2                     Rua Oscar Freire                Pinheiros    18
# 3                     Rua Júlio Sayago                  Vila Ré    56
# 4                   Rua Barata Ribeiro               Bela Vista    19
# ...                                ...                      ...   ...
# 11652          Avenida Adolfo Pinheiro              Santo Amaro    94
# 11653  Rua Professor Alexandre Correia     Jardim Vitória Régia   350
# 11654                 Rua Abílio Borin         Jardim Caravelas    84
# 11655                Rua Forte William  Jardim Fonte do Morumbi    76
# 11656              Rua Alexandre Dumas              Santo Amaro   110
#
#        quartos  garagem                tipo  aluguel  valor_total  \
# ...

# %%
condicao2 = (dados_sp['tipo'] == 'Studio e kitnet') & (dados_sp['aluguel'] >20000)
dados_sp= dados_sp.loc[~condicao2]
dados_sp
# Out:
#                               endereço                 distrito  área  \
# 0                           Rua Herval               Belenzinho    21
# 1                   Avenida São Miguel             Vila Marieta    15
# 2                     Rua Oscar Freire                Pinheiros    18
# 3                     Rua Júlio Sayago                  Vila Ré    56
# 4                   Rua Barata Ribeiro               Bela Vista    19
# ...                                ...                      ...   ...
# 11652          Avenida Adolfo Pinheiro              Santo Amaro    94
# 11653  Rua Professor Alexandre Correia     Jardim Vitória Régia   350
# 11654                 Rua Abílio Borin         Jardim Caravelas    84
# 11655                Rua Forte William  Jardim Fonte do Morumbi    76
# 11656              Rua Alexandre Dumas              Santo Amaro   110
#
#        quartos  garagem                tipo  aluguel  valor_total  \
# ...

# %%
dados_sp.tail()
# Out:
#                               endereço                 distrito  área  \
# 11652          Avenida Adolfo Pinheiro              Santo Amaro    94
# 11653  Rua Professor Alexandre Correia     Jardim Vitória Régia   350
# 11654                 Rua Abílio Borin         Jardim Caravelas    84
# 11655                Rua Forte William  Jardim Fonte do Morumbi    76
# 11656              Rua Alexandre Dumas              Santo Amaro   110
#
#        quartos  garagem         tipo  aluguel  valor_total  valor_por_m2  \
# 11652        2        1  Apartamento     4100         5778     43.617021
# 11653        4        4  Apartamento    11250        17480     32.142857
# 11654        1        2  Apartamento     4500         5467     53.571429
# 11655        1        0  Apartamento     9000        10200    118.421053
# 11656        3        1         Casa     3300         3440     30.000000
#
#        custo
# 11652   1678
# 11653   6230
# 11654    967
# 11655   1200
# 11656    140

# %%
dados_sp.quartos.unique()
# Out:
# array([1, 2, 3, 0, 4, 5, 6])

# %% [markdown]
# ### Análise Descritiva

# %%
dados_sp.tipo.unique()
# Out:
# array(['Studio e kitnet', 'Apartamento', 'Casa em condomínio', 'Casa'],
#       dtype=object)

# %%
dados_sp.groupby("tipo").mean(numeric_only=True)
# Out:
#                           área   quartos   garagem      aluguel  valor_total  \
# tipo
# Apartamento          73.366824  1.989841  1.023379  3359.015864  4438.212914
# Casa                136.184155  2.353521  1.514789  3472.020423  3824.410915
# Casa em condomínio  119.414938  2.236515  1.414938  3912.551867  4576.232365
# Studio e kitnet      31.676577  1.005801  0.258883  2110.606962  2650.460479
#
#                     valor_por_m2        custo
# tipo
# Apartamento            48.477069  1079.197050
# Casa                   27.698590   352.390493
# Casa em condomínio     68.292817   663.680498
# Studio e kitnet        72.070136   539.853517

# %%
dados_sp.groupby("distrito")["valor_total"].mean()
# Out:
# distrito
# Aclimação                                                  3622.300000
# Adalgisa                                                   8932.500000
# Agua Branca                                                2919.000000
# Alphaville                                                13159.583333
# Alphaville Centro Industrial E Empresarial/alphaville.     7720.400000
#                                                               ...
# Várzea da Barra Funda                                      4424.272727
# Água Branca                                                4745.227273
# Água Fria                                                  4658.800000
# Água Funda                                                 3759.000000
# Água Rasa                                                  3329.947368
# Name: valor_total, Length: 1199, dtype: float64

# %%
dados_sp.groupby(['quartos'])["valor_total"].mean()
# Out:
# quartos
# 0    2804.366667
# 1    2696.107586
# 2    3443.849057
# 3    6035.745665
# 4    9968.303867
# 5    9999.846154
# 6    9893.136364
# Name: valor_total, dtype: float64

# %%
dados_sp.groupby("tipo")[["aluguel"]].mean().sort_values('aluguel')
# Out:
#                         aluguel
# tipo
# Studio e kitnet     2110.606962
# Apartamento         3359.015864
# Casa                3472.020423
# Casa em condomínio  3912.551867

# %%
df_preco =dados_sp.groupby("tipo")[["aluguel"]].mean().sort_values('aluguel')


df_preco.plot(kind='barh', figsize=(14, 10), color ='green');

### Entender visualmente e em gráfico o comportamento do aluguel por tipo

# %%
df_preco =dados_sp.groupby("tipo")[["custo"]].mean().sort_values('custo')


df_preco.plot(kind='barh', figsize=(14, 10), color ='orange');


### Entender visualmente e em gráfico o comportamento do aluguel por custo

# %%
dados_sp["tipo"].value_counts()
# Out:
# tipo
# Apartamento           7186
# Casa                  2840
# Studio e kitnet       1379
# Casa em condomínio     241
# Name: count, dtype: int64

# %%
dados_sp["tipo"].value_counts(normalize = True) *100
# Out:
# tipo
# Apartamento           61.703589
# Casa                  24.386055
# Studio e kitnet       11.840975
# Casa em condomínio     2.069380
# Name: proportion, dtype: float64

# %%
frequencia = dados_sp['tipo'].value_counts()

# %%
percentual = dados_sp['tipo'].value_counts(normalize = True) *100

# %%
dist_freq_qualitativas = pd.DataFrame({'Frequência':frequencia , 'Porcentagem (%)':percentual})

# %%
dist_freq_qualitativas
# Out:
#                     Frequência  Porcentagem (%)
# tipo
# Apartamento               7186        61.703589
# Casa                      2840        24.386055
# Studio e kitnet           1379        11.840975
# Casa em condomínio         241         2.069380

# %%
dados_sp["quartos"].value_counts()
# Out:
# quartos
# 2    4346
# 1    4192
# 3    2422
# 4     543
# 5      91
# 0      30
# 6      22
# Name: count, dtype: int64

# %%
tipo = { 0 : "Apartamento", 1: "Casa", 2 :"Studio e kitnet", 3 :"Casa em condominio"}
quartos = {1,2,3,4,5,6}

# %%
frequencia = pd.crosstab(dados_sp.tipo,dados_sp.quartos)
frequencia
# Out:
# quartos              0     1     2     3    4   5   6
# tipo
# Apartamento          0  2047  3418  1482  227  10   2
# Casa                 4   762   798   891  291  75  19
# Casa em condomínio   0    64    96    49   25   6   1
# Studio e kitnet     26  1319    34     0    0   0   0

# %%
dados_sp.groupby("tipo")["valor_total"].mean()
# Out:
# tipo
# Apartamento           4438.212914
# Casa                  3824.410915
# Casa em condomínio    4576.232365
# Studio e kitnet       2650.460479
# Name: valor_total, dtype: float64

# %%
ax = sns.distplot(dados_sp.quartos, kde = False)

ax.figure.set_size_inches(12, 6)
ax.set_title('Distribuição de Frequências - Quartos ', fontsize=18)
ax.set_xlabel('Quartos disponiveis ', fontsize=14)
ax
# Out:
# <ipython-input-41-bb880cfa3ca3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dados_sp.quartos, kde = False)
# <Axes: title={'center': 'Distribuição de Frequências - Quartos '}, xlabel='Quartos disponiveis '>

# %%
ax = sns.distplot(dados_sp.quartos)

ax.figure.set_size_inches(12, 6)
ax.set_title('Distribuição de Frequências - Quartos  - KDE', fontsize=18)
ax.set_xlabel('Quartos disponiveis', fontsize=14)
ax
# Out:
# <ipython-input-42-e670be21e599>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dados_sp.quartos)
# <Axes: title={'center': 'Distribuição de Frequências - Quartos  - KDE'}, xlabel='Quartos disponiveis', ylabel='Density'>

# %%
dados_sp.aluguel.median()
# Out:
# 2420.0

# %%
dados_sp.aluguel.quantile()
# Out:
# 2420.0

# %%
dados_sp.aluguel.mode()
# Out:
# 0    3000
# Name: aluguel, dtype: int64

# %%
dados_sp.aluguel.var()
# Out:
# 6989953.961394205

# %%
dados_sp.aluguel.std()
# Out:
# 2643.852106566138

# %% [markdown]
# ### Análises Gráficas

# %%
ax = sns.boxplot( x = 'custo', data = dados_sp, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Custo', fontsize=18)
ax.set_xlabel('Reais', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Custo'}, xlabel='Reais'>

# %%
ax = sns.boxplot( x = 'área', data = dados_sp, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Área', fontsize=18)
ax.set_xlabel('Metros²', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Área'}, xlabel='Metros²'>

# %%
ax = sns.boxplot( x = 'quartos', y = 'tipo', data = dados_sp, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Tipo x Quartos', fontsize=18)
ax.set_xlabel('quartos', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Tipo x Quartos'}, xlabel='quartos', ylabel='tipo'>

# %%
ax = sns.boxplot( y = 'tipo', x = 'aluguel', data = dados_sp, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Tipo x Valor do Aluguel', fontsize=18)
ax.set_xlabel('R$', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Tipo x Valor do Aluguel'}, xlabel='R$', ylabel='tipo'>

# %%
ax = sns.boxplot( y = 'tipo', x = 'custo', data = dados_sp, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Tipo x Custo', fontsize=18)
ax.set_xlabel('R$', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Tipo x Custo'}, xlabel='R$', ylabel='tipo'>

# %%
ax = sns.boxplot( y = 'tipo', x = 'quartos', data = dados_sp, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Tipo x Quartos', fontsize=18)
ax.set_xlabel('Quantidade de quartos', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Tipo x Quartos'}, xlabel='Quantidade de quartos', ylabel='tipo'>

# %%
ax = sns.boxplot( y = 'quartos', x = 'aluguel', data = dados_sp, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Quarto x Valor do Aluguel', fontsize=18)
ax.set_xlabel('R$', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Quarto x Valor do Aluguel'}, xlabel='R$', ylabel='quartos'>

# %%
ax = sns.boxplot( y = 'garagem', x = 'aluguel', data = dados_sp, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Garagem x Valor do Aluguel', fontsize=18)
ax.set_xlabel('R$', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Garagem x Valor do Aluguel'}, xlabel='R$', ylabel='garagem'>

# %% [markdown]
# ### Matriz de correlação

# %%
dados_sp.corr(numeric_only = True).round(4)

### Apartir da análise de correlação verifica-se que o aluguel está relacionado principalmente com as váriaveis : área , quartos , garagem e custo .
# Out:
#                 área  quartos  garagem  aluguel  valor_total  valor_por_m2  \
# área          1.0000   0.7287   0.7335   0.6697       0.6538       -0.1074
# quartos       0.7287   1.0000   0.6568   0.5339       0.5281       -0.0811
# garagem       0.7335   0.6568   1.0000   0.6197       0.6198       -0.0239
# aluguel       0.6697   0.5339   0.6197   1.0000       0.9781        0.1245
# valor_total   0.6538   0.5281   0.6198   0.9781       1.0000        0.1188
# valor_por_m2 -0.1074  -0.0811  -0.0239   0.1245       0.1188        1.0000
# custo         0.4450   0.3792   0.4641   0.6706       0.8103        0.0729
#
#                custo
# área          0.4450
# quartos       0.3792
# garagem       0.4641
# aluguel       0.6706
# valor_total   0.8103
# valor_por_m2  0.0729
# custo         1.0000

# %% [markdown]
# ### Comportamento do Aluguel

# %%
ax = sns.boxplot(data=dados_sp['aluguel'], orient='h', width=0.2)
ax.figure.set_size_inches(12, 6)
ax.set_title('Valor do Aluguel', fontsize=20)
ax.set_ylabel('$', fontsize=16)
ax
# Out:
# <Axes: title={'center': 'Valor do Aluguel'}, xlabel='aluguel', ylabel='$'>

# %%
ax = sns.distplot(dados_sp["aluguel"])
ax.figure.set_size_inches(12, 6)
ax.set_title('Distribuição do aluguel', fontsize=20)
ax.set_ylabel('Densidade', fontsize=16)
ax.set_xlabel('$', fontsize=16)
ax
# Out:
# <ipython-input-56-5ad4affc4dad>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dados_sp["aluguel"])
# <Axes: title={'center': 'Distribuição do aluguel'}, xlabel='$', ylabel='Densidade'>

# %%
ax = sns.pairplot(dados_sp, y_vars='aluguel', x_vars=['área', 'garagem', 'quartos', 'custo'])
ax.fig.suptitle('Dispersão entre as Variáveis', fontsize=20, y=1.05)
ax

# %%
ax = sns.pairplot(dados_sp, y_vars='aluguel', x_vars=['área', 'garagem', 'quartos', 'custo'],kind ='reg')
ax.fig.suptitle('Dispersão entre as Variáveis', fontsize=20, y=1.05)
ax

# %% [markdown]
# ### Estimação da regressão linear com a variável sem  custo

# %%
from sklearn.model_selection import train_test_split

# %%
y = dados_sp['aluguel']

# %%
X = dados_sp[['área', 'garagem', 'quartos']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2811)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
modelo = LinearRegression()

# %%
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('R² = {}'.format(modelo.score(X_train, y_train).round(2)))
# Out:
# R² = 0.48

# %%
y_previsto = modelo.predict(X_test)

# %%
print('R² = %s' % metrics.r2_score(y_test, y_previsto).round(2))
# Out:
# R² = 0.5

# %% [markdown]
# ### Estimação da regressão linear com a variável com custo

# %%
from sklearn.model_selection import train_test_split

# %%
y = dados_sp['aluguel']

# %%
X = dados_sp[['área', 'garagem', 'quartos',"custo"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2811)

# %%
X_train.shape
# Out:
# (8152, 4)

# %%
X_test.shape
# Out:
# (3494, 4)

# %%
X_train.shape[0] + X_test.shape[0]
# Out:
# 11646

# %%
X.shape[0] * 0.3
# Out:
# 3493.7999999999997

# %%
X.shape[0] * 0.7
# Out:
# 8152.2

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
modelo = LinearRegression()

# %%
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('R² = {}'.format(modelo.score(X_train, y_train).round(2)))
# Out:
# R² = 0.62

# %%
y_previsto = modelo.predict(X_test)

# %%
print('R² = %s' % metrics.r2_score(y_test, y_previsto).round(2))
# Out:
# R² = 0.66

# %% [markdown]
# ###  Previsões pontuais

# %%
área=25
garagem=1
quartos=2
custo = 350


entrada= np.array([[área, garagem, quartos,custo]])

predicao = modelo.predict(entrada)

print(f'$ {predicao[0]:.2f}')
# Out:
# $ 1907.28
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Interpretação dos Coeficientes Estimados

# %%
modelo.intercept_
# Out:
# 802.447316156226

# %%
modelo.coef_
# Out:
# array([ 12.56076011, 372.21251133,   1.47617869,   1.1875734 ])

# %% [markdown]
# ### A ordem das variáveis explicativas no DataFrame

# %%
X.columns
# Out:
# Index(['área', 'garagem', 'quartos', 'custo'], dtype='object')

# %% [markdown]
# ## Lista com os nomes das variáveis do modelo

# %%
index =['Intercepto','Área','Garagem','Quartos','Custo']

# %% [markdown]
# ### DataFrame para armazenar os coeficientes do modelo

# %%
pd.DataFrame(data=np.append(modelo.intercept_, modelo.coef_), index=index, columns=['Parâmetros'])
# Out:
#             Parâmetros
# Intercepto  802.447316
# Área         12.560760
# Garagem     372.212511
# Quartos       1.476179
# Custo         1.187573

# %% [markdown]
# ## Análises Gráficas das Previsões do Modelo

# %% [markdown]
# ### Gerando as previsões do modelo para os dados de TREINO

# %%
y_previsto_train = modelo.predict(X_train)

# %%
ax = sns.scatterplot(x=y_previsto_train, y=y_train)
ax.figure.set_size_inches(12, 6)
ax.set_title('Previsão X Real', fontsize=18)
ax.set_xlabel('Aluguel (R$) - Previsão', fontsize=14)
ax.set_ylabel('Aluguel (R$) - Real', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Previsão X Real'}, xlabel='Aluguel (R$) - Previsão', ylabel='Aluguel (R$) - Real'>

# %% [markdown]
# ### Obtendo os resíduos

# %%
residuo = y_train - y_previsto_train

# %% [markdown]
# ### Gráfico de dispersão entre valor estimado e resíduos

# %%
ax = sns.scatterplot(x=y_previsto_train, y=residuo, s=150)
ax.figure.set_size_inches(20, 8)
ax.set_title('Resíduos X Previsão', fontsize=18)
ax.set_xlabel('Aluguel (R$) - Previsão', fontsize=14)
ax.set_ylabel('Resíduos', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Resíduos X Previsão'}, xlabel='Aluguel (R$) - Previsão', ylabel='Resíduos'>

# %% [markdown]
# ### Conclusões

# %% [markdown]
# *   Na base de dados foi feito a  limpeza e tratamento das informações onde a área tinha o valor igual a zero . Além disso , foi removido dados aonde tinha o tipo como apartamento e com zero quartos .Por fim foi tratado outras informações , aonde  notei na aálise  que poderiam ser "outliers" na análise de dados, como tipo igual a  studio e kitnet e igual a seis quartos  .
#
# *   As variáveis área , custo , garagem ,quartos tem impacto direto na análise do aluguel.
#
# *   Na base de alugueis de São Paulo nota-se que o valor do aluguel  mais caro está em casa de condomínio e em casas.
#
# *   Existe uma tendência de valor crescente do aluguel , ao aumentar o número de quartos e garagens .
#
# *   Ao fazer a estimação no modelo de regressão linear com a variável custo e sem a variável custo notou-se que o primeiro teve  um maior valor de R² aplicado ao modelo de treino e de teste , com isso pode-se concluir que a variável custo tem impacto ao se anlisar sua relação com o aluguel.
#
#
# *   Analisando os valores do resíduos em comparação com  o aluguel nota-se que os valores apresentam padrões irregulares .
